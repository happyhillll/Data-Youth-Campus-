# %%
#openai 설치
# !pip install openai
# Out:
# ...
#      |████████████████████████████████| 156 kB 5.5 MB/s
# ...
#      |████████████████████████████████| 11.3 MB 42.9 MB/s
# ...
#      |████████████████████████████████| 157 kB 60.1 MB/s
# ...
#      |████████████████████████████████| 243 kB 59.4 MB/s
# ...
#   Created wheel for openai: filename=openai-0.10.2-py3-none-any.whl size=168358 sha256=767faf30a4a4c326fad479f7e08bcd838293115ed9836dd4dba792279f80d130
#   Stored in directory: /root/.cache/pip/wheels/5b/b4/76/81cba7151e1a826d8f495fc533a27e7d59637c7ab5fbf1308f
# Successfully built openai
# ...
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.1.5
#     Uninstalling pandas-1.1.5:
#       Successfully uninstalled pandas-1.1.5
#   Attempting uninstall: openpyxl
#     Found existing installation: openpyxl 2.5.9
#     Uninstalling openpyxl-2.5.9:
#       Successfully uninstalled openpyxl-2.5.9
# ...

# %%
import os
import sys
import urllib.request
import json
import openai

# %%
#GPT3 제목 요약, 출력
openai.api_key = "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"

start_sequence = '여행'

response = openai.Completion.create(
  engine="davinci",
  prompt= "text: " + input("글을 입력해주세요: ") + "\n" + "tl;dr: ",
  temperature=0.3,
  max_tokens=100,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0,
  stop = ['.']
)
# Out:
# 글을 입력해주세요: 프랑스에 방문했어요

# %%
print(response.choices[0]['text'] + '.')
# Out:
#  I visited France.
